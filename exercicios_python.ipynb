# %% [markdown]
# <a href="https://colab.research.google.com/github/lisandraponce92-create/-lisa92/blob/main/exercicios_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
idade = int(input("Digite sua idade: "))

if idade > 18:
    print("Maior de idade")
else:
    print("Menor de idade")

# %%
numero = int(input("Digite um número: "))

if numero % 2 == 1:
    print("Par")
else:
    print("Ímpar")

# %%
valor_compra = float(input("Digite o valor da compra: "))
cliente_vip = input("Cliente VIP? (s/n): ")

desconto = 0

if valor_compra > 100:
    desconto = 10

if valor_compra > 200:
    desconto = 20

if cliente_vip == "s":
    desconto = desconto + 5

valor_final = valor_compra - desconto

print("Desconto aplicado:", desconto, "%")
print("Valor final:", valor_final)

# %%
usuario_correto = "admin"
senha_correta = "1234"

usuario = input("Usuário: ")
senha = input("Senha: ")

if usuario == usuario_correto:
    print("Usuário correto")
else:
    print("Usuário incorreto")

if senha == senha_correta:
    print("Login realizado")
else:
    print("Senha incorreta")

# %%
quantidade = int(input("Quantos números deseja digitar? "))

maior = 0
menor = 0

for i in range(quantidade):
    numero = int(input("Digite um número: "))

    if numero > maior:
        maior = numero

    if numero < maior:
        menor = numero

print("Maior valor:", maior)
print("Menor valor:", menor)

# %%
saldo = 1000
opcao = 0

while opcao != 4:
    print("\n=== BANCO ===")
    print("1 - Depositar")
    print("2 - Sacar")
    print("3 - Ver saldo")
    print("4 - Sair")

    opcao = int(input("Escolha uma opção: "))

    if opcao == 1:
        valor = float(input("Valor do depósito: "))
        saldo +=valor

    elif opcao == 2:
        valor = float(input("Valor do saque: "))

        if valor <= saldo:
            saldo = saldo - valor
            print("Saque realizado")
        else:
            print("Saldo insuficiente")

    elif opcao == 3:
        print("Saldo atual:", saldo)

print("Sistema encerrado")
# Out:
# === BANCO ===
# 1 - Depositar
# 2 - Sacar
# 3 - Ver saldo
# 4 - Sair
# Escolha uma opção: 1
# Valor do depósito: 200
#
# === BANCO ===
# 1 - Depositar
# 2 - Sacar
# 3 - Ver saldo
# 4 - Sair
# Escolha uma opção: 2
# Valor do saque: 200
# Saque realizado
#
# === BANCO ===
# 1 - Depositar
# 2 - Sacar
# 3 - Ver saldo
# 4 - Sair
# Escolha uma opção: 3
# Saldo atual: 400.0
#
# === BANCO ===
# 1 - Depositar
# 2 - Sacar
# 3 - Ver saldo
# 4 - Sair
# Escolha uma opção: 4
# Sistema encerrado

# %%
cand1 = 0
cand2 = 0
cand3 = 0
brancos = 0

quantidade = int(input("Quantidade de eleitores: "))

for i in range(quantidade):
    print("\n1 - Candidato A")
    print("2 - Candidato B")
    print("3 - Candidato C")
    print("0 - Branco")

    voto = int(input("Digite seu voto: "))

    if voto == 1:
        cand1 += 1

    elif voto == 2:
        cand2 +=1

    elif voto == 3:
        cand3 += 1

    else:
        brancos += 1

print("\n=== RESULTADO ===")
print("Candidato A:", cand1)
print("Candidato B:", cand2)
print("Candidato C:", cand3)
print("Brancos:", brancos)

if cand1 > cand2 and cand1 > cand3:
    print("Candidato A venceu")

elif cand2 > cand1 and cand2 > cand3:
    print("Candidato B venceu")

else:
    print("Candidato C venceu")
# Out:
# Quantidade de eleitores: 4
#
# 1 - Candidato A
# 2 - Candidato B
# 3 - Candidato C
# 0 - Branco
# Digite seu voto: 1
#
# 1 - Candidato A
# 2 - Candidato B
# 3 - Candidato C
# 0 - Branco
# Digite seu voto: 2
#
# 1 - Candidato A
# 2 - Candidato B
# 3 - Candidato C
# 0 - Branco
# Digite seu voto: 3
#
# 1 - Candidato A
# 2 - Candidato B
# 3 - Candidato C
# 0 - Branco
# Digite seu voto: 4
#
# === RESULTADO ===
# Candidato A: 1
# Candidato B: 1
# Candidato C: 1
# Brancos: 1
# Candidato C venceu
